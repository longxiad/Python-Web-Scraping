# %%
# 腾讯招聘网爬虫作业

from lxml import etree
import requests

BASE_DOMAIN = "http://hr.tencent.com/"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36",
    "Cookie": "ts_refer=www.baidu.com/link; pgv_pvid=6696594441; ts_uid=3711980616; PHPSESSID=npfgl3krhdbvp369bcdqlnmof5",
    "Host": "hr.tencent.com",
    "Upgrade-Insecure-Requests":"1"
}

def parse_detail_page(url):
    position = {}
    response = requests.get(url,headers=HEADERS)
    html = etree.HTML(response.text)
    title = html.xpath("//td[@id='sharetitle']/text()")[0]
    tds = html.xpath("//tr[@class='c bottomline']/td")
    address = tds[0].xpath(".//text()")[1]
    category = tds[1].xpath(".//text()")[1]
    nums = tds[2].xpath(".//text()")[1]
    more_infos = html.xpath("//ul[@class='squareli']")
    duty = more_infos[0].xpath(".//text()")
    require = more_infos[1].xpath(".//text()")

    position['title'] = title
    position['address'] = address
    position['category'] = category
    position['nums'] = nums
    position['duty'] = duty
    position['require'] = require
    return position


def get_detail_urls(url):
    response = requests.get("http://hr.tencent.com/position.php?lid=&tid=&keywords=python&start=0",headers=HEADERS)
    text = response.text
    html = etree.HTML(text)
    links = html.xpath("//tr[@class='even' or @class='even']//a/@href")
    links = map(lambda url:BASE_DOMAIN+url,links)
    return links

def spider():
    base_url = "http://hr.tencent.com/position.php?lid=&tid=&keywords=python&start={}"
    positions = []
    for x in range(0,43):
        x *= 10
        url = base_url.format(x)
        detail_urls = get_detail_urls(url)
        for detail_url in detail_urls:
            position = parse_detail_page(detail_url)
            positions.append(position)
            print(position)
    # print(positions)

if __name__ == '__main__':
    spider()
# Out:
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# ...
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
# {'title': '26564-后台开发工程师(深圳）', 'address': '深圳', 'category': '技术类', 'nums': '1人', 'duty': ['负责移动游戏社区APP后台服务架构设计开发；', '负责移动游戏社区平台用户数据分析及相关推荐业务开发；', '负责移动游戏实时语音业务系统开发。'], 'require': ['本科及以上学历，计算机相关专业；', '具备Unix/Linux下C/C++ 2到5年开发经验；', '精通C++和面向对象的设计与开发；', '精通TCP/IP协议，进程间通讯编程，熟悉Unix/Linux下常用架构设计方法；', '熟悉Unix/Linux操作系统原理，常用工具、Python/Shell等脚本语言等；', '熟悉Mysql数据库管理、开发; 熟悉redis等NoSQL存储使用', '具备良好的分析解决问题能力，能独立承担任务和有系统进度把控能力；', '责任心强，良好的对外沟通和团队协作能力，主动，好学；', '熟悉Go语言开发，有机器学习开发经验者优先。']}
# {'title': 'WXG02-116 微信搜索和信息流系统测试工程师（广州）', 'address': '广州', 'category': '技术类', 'nums': '1人', 'duty': ['测试大规模软件项目（比如微信），并开发测试工具； ', '设计具有高度扩展性、可靠性强、与高性能的测试框架； ', '优化软件开发周期，提高产品质量，推动内建的产品质量； ', '测试方法/工具的创新。'], 'require': ['本科（含）以上学历，成绩优秀； ', '至少精通以下一种语言: C/C++, Java 或 Python； ', '扎实的计算机专业知识，出色的编程能力，以及系统设计能力； ', '对Internet/web相关知识有深入了解，如，Http，Html等； ', '对测试方法，常用技术，以及web应用有深入且广泛的了解； ', '英语熟练（尤其是读写方面）； ', '具有Unix/Linux相关经验尤佳； ', '具有信息流/推荐/搜索或者人工智能项目相关经验尤佳。']}
# {'title': 'WXG08-113 微信推荐策略开发工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['负责微信看一看在线策略的开发', '负责推荐产品逻辑的实现、实验以及线上效果分析', '负责推荐相关的规则、保量、模型等平台或系统的设计与实现。'], 'require': ['有1-5年的Linux C/C++ 后台高性能服务器开发经验和数据分析处理经验；', '熟悉python/perl/bash 中的一到多种脚本编程；', '熟练掌握各类常用数据结构和相关算法；', '熟悉分布式系统的设计和应用，熟悉分布式缓存、消息等机制，并能合理应用分布式技术；', '责任感强、有较强的逻辑思维能力、沟通能力；', '有搜索/推荐后台经验优先；']}
# {'title': 'SA-社交与效果广告创意洞察研究经理（北京）', 'address': '北京', 'category': '市场类', 'nums': '1人', 'duty': ['基于腾讯社交广告的数据资源开展社交洞察工作，包括但不限于：', '深入了解行业动态，开展有针对性的行业用户洞察研究；', '聚焦广告创意问题挖掘，完成基于用户洞察的素材分析和优化指导方案；', '具备较强的数据分析能力，能整合多方数据源，完成行业洞察、创意营销方案等工作内容。'], 'require': ['3+工作经验；', '硕士或以上学历，社会学、统计学、经济管理学科专业优先；', '对商业分析、市场研究有研究经验和自己的见解；', '数据分析、逻辑能力强，熟练掌握 EXCEL、SPSS、SQL/R/Python、PPT操作；', '熟悉广告、网络、媒体运营模式（有互联网或 4A 公司工作背景优先）；', '能适应压力下的工作环境，高度的责任心，工作勤恳努力，团队合作意识好，善于和人沟通。']}
# {'title': 'WXG01-122 自然语言处理算法工程师（北京）', 'address': '北京', 'category': '技术类', 'nums': '1人', 'duty': ['使用机器学习、文本挖掘等技术，对微信朋友圈、公众平台文本数据进行分析挖掘；', '基于微信大数据构建吃喝玩乐相关的用户生活画像体系和POI商户画像体系；', '负责用户吃喝玩乐相关搜索查询意图语义分析理解和推荐排序特征的挖掘；'], 'require': ['计算机相关专业，扎实的数据结构和算法功底，精通至少一种编程语言：C、C++、python；', '熟悉常用的NLP、文本挖掘、机器学习算法，有深度学习背景者优先；', '熟悉Linux开发环境，熟悉Hadoop、Spark等大数据计算平台；', '两年以上自然语言处理或数据挖掘相关工作经验，有搜索、推荐项目背景者优先；', '对以上工作内容具有激情，良好的沟通能力，有团队精神；']}
