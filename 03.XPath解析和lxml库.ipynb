# %% [markdown]
# # 1. XPath语法和lxml模块
# ### 什么是XPath？
# xpath（XML Path Language）是一门在XML和HTML文档中查找信息的语言，可用来在XML和HTML文档中对元素和属性进行遍历。
#
# ### XPath开发工具
# 1. Chrome插件XPath Helper
# 2. Firefox插件Try XPath

# %% [markdown]
# # xpath语法：

# %% [markdown]
# ### 1.选取节点
# 1. nodename 选取此节点的所有子节点
# 2. / 如果是在最前面，代表从根节点寻去。否则选择某节点下的某个节点
# 3. // 从全局节点中选择节点，随便在哪个位置
# 4. @ 选取某个节点的属性
#
# /bookstore/book 查找bookstore节点下的book子节点
# //book 查找所有的book节点
# //book//price 获取所有book下的所有price标签
# .//price 获取当前节点下的所有price标签
# //book[@price] 选取拥有price属性的book元素
#
# ### 2.谓语（指定条件）
# 中括号里的东西
# 1. /bookstore/book[1] 选取bookstore下的第一个子元素
# 2. /bookstore/book[last()] 选取bookstore下的最后一个元素
# 3. /bookstore/book[position()<3] 选取bookstore下前面两个子元素
# 4. //book[@price] 选取拥有price属性的book元素
# 5. //book[@price=10] 选取所有属性price等于10的book元素
# 6. //book[contains(@class, "fl")] **模糊匹配**。选取class属性中包含"fl"的素有book元素
#
# ### 3.通配符（任意）
# 1. \* 匹配任意节点
# 2. @\* 匹配节点中的任何属性
# /bookstore/\* 选取bookstore下的所有子元素。
# //book[@\*] 选取所有带有属性的book元素。
#
# ### 4.选取多个路径
# 1. |
# //bookstore/book | //book/title 选取所有
# //dd[@class='job_bt'] | //dd[@class="job-advantage" 获取所有带有class是job_bot或者clas是job-advantage属性的dd元素
#
# ### 5.运算符
# 1. or
# 2. and
# 3. +
# 4. -
# 5. \>
# 6. <
# 7. =
# 8. \>=
# 9. ...
#
# (//dl[@class="job_detail" and @id="job_detial"])

# %% [markdown]
# ## 总结: xpath语法：
#
# ### 使用方式：
# 使用//获取整个页面当中的元素，然后写标签名，然后再写谓词进行提取。比如：
# ```
# //div[@class='abc']
# ```
#
# ### 需要注意的知识点：
# 1. /和//的区别：/代表只获取直接子节点。//获取子孙节点。一般//用得比较多。当然也要视情况而定。
# 2. contains：有时候某个属性中包含了多个值，那么可以使用`contains`函数。示例代码如下：
#     ```
#     //div[contains(@class,'job_detail')]
#     ```
# 3. 谓词中的下标是从1开始的，不是从0开始的。

# %% [markdown]
# # 2. 使用lxml解析HTML代码：
# 1. 解析html字符串：使用`lxml.etree.HTML`进行解析。示例代码如下：
#     ```python
#     htmlElement = etree.HTML(text)
#     print(etree.tostring(htmlElement,encoding='utf-8').decode("utf-8"))
#     ```
# 2. 解析html文件：使用`lxml.etree.parse`进行解析。示例代码如下：
#     ```python
#     htmlElement = etree.parse("tencent.html")
#     print(etree.tostring(htmlElement, encoding='utf-8').decode('utf-8'))
#     ```
#     这个函数默认使用的是`XML`解析器，所以如果碰到一些不规范的`HTML`代码的时候就会解析错误，这时候就要自己创建`HTML`解析器。
#     ```python
#     parser = etree.HTMLParser(encoding='utf-8')
#     htmlElement = etree.parse("lagou.html",parser=parser)
#     print(etree.tostring(htmlElement, encoding='utf-8').decode('utf-8'))
#     ```
#
#     ## lxml结合xpath注意事项：
#     1. 使用`xpath`语法。应该使用`Element.xpath`方法。来执行xpath的选择。示例代码如下：
#         ```python
#         trs = html.xpath("//tr[position()>1]")
#         ```
#     `xpath函数`返回来的永远是一个列表。
#     2. 获取某个标签的属性：
#         ```python
#         href = html.xpath("//a/@href")
#         # 获取a标签的href属性对应的值
#         ```
#     3. 获取文本，是通过`xpath`中的`text()`函数。示例代码如下：
#         ```python
#         address = tr.xpath("./td[4]/text()")[0]
#         ```
#     4. 在某个标签下，再执行xpath函数，获取这个标签下的子孙元素，那么应该在斜杠之前加一个点，代表是在当前元素下获取。示例代码如下：
#         ```python
#          address = tr.xpath("./td[4]/text()")[0]
#         ```

# %% [markdown]
# ### 使用lxml解析HTML代码

# %%
from lxml import etree #c语言写的

# %%
text = """
<table class="tablelist" cellpadding="0" cellspacing="0">
    <tbody>
        <tr class="h">
            <td class="l" width="374">职位名称</td>
            <td>职位类别</td>
            <td>人数</td>
            <td>地点</td>
            <td>发布时间</td>
        </tr>
        <tr class="even">
            <td class="l square"><a target="_blank" href="position_detail.php?id=33824&keywords=python&tid=87&lid=2218">22989-金融云区块链高级研发工程师（深圳）</a></td>
            <td>技术类</td>
            <td>1</td>
            <td>深圳</td>
            <td>2017-11-25</td>
        </tr>
        <tr class="odd">
            <td class="l square"><a target="_blank" href="position_detail.php?id=29938&keywords=python&tid=87&lid=2218">22989-金融云高级后台开发</a></td>
            <td>技术类</td>
            <td>2</td>
            <td>深圳</td>
            <td>2017-11-25</td>
        </tr>
        <tr class="even">
            <td class="l square"><a target="_blank" href="position_detail.php?id=31236&keywords=python&tid=87&lid=2218">SNG16-腾讯音乐运营开发工程师（深圳）</a></td>
            <td>技术类</td>
            <td>2</td>
            <td>深圳</td>
            <td>2017-11-25</td>
        </tr>
        <tr class="odd">
            <td class="l square"><a target="_blank" href="position_detail.php?id=31235&keywords=python&tid=87&lid=2218">SNG16-腾讯音乐业务运维工程师（深圳）</a></td>
            <td>技术类</td>
            <td>1</td>
            <td>深圳</td>
            <td>2017-11-25</td>
        </tr>
        <tr class="even">
            <td class="l square"><a target="_blank" href="position_detail.php?id=34531&keywords=python&tid=87&lid=2218">TEG03-高级研发工程师（深圳）</a></td>
            <td>技术类</td>
            <td>1</td>
            <td>深圳</td>
            <td>2017-11-24</td>
        </tr>
        <tr class="odd">
            <td class="l square"><a target="_blank" href="position_detail.php?id=34532&keywords=python&tid=87&lid=2218">TEG03-高级图像算法研发工程师（深圳）</a></td>
            <td>技术类</td>
            <td>1</td>
            <td>深圳</td>
            <td>2017-11-24</td>
        </tr>
        <tr class="even">
            <td class="l square"><a target="_blank" href="position_detail.php?id=31648&keywords=python&tid=87&lid=2218">TEG11-高级AI开发工程师（深圳）</a></td>
            <td>技术类</td>
            <td>4</td>
            <td>深圳</td>
            <td>2017-11-24</td>
        </tr>
        <tr class="odd">
            <td class="l square"><a target="_blank" href="position_detail.php?id=32218&keywords=python&tid=87&lid=2218">15851-后台开发工程师</a></td>
            <td>技术类</td>
            <td>1</td>
            <td>深圳</td>
            <td>2017-11-24</td>
        </tr>
        <tr class="even">
            <td class="l square"><a target="_blank" href="position_detail.php?id=32217&keywords=python&tid=87&lid=2218">15851-后台开发工程师</a></td>
            <td>技术类</td>
            <td>1</td>
            <td>深圳</td>
            <td>2017-11-24</td>
        </tr>
        <tr class="odd">
            <td class="l square"><a target="_blank" href="position_detail.php?id=34511&keywords=python&tid=87&lid=2218">SNG11-高级业务运维工程师（深圳）</a></td>
            <td>技术类</td>
            <td>1</td>
            <td>深圳</td>
            <td>2017-11-24</td>
        </tr>
    </tbody>
</table>
"""
# Out:
# <class 'str'>

# %%
#用HTML这个类去解析html字符串
htmlElement = etree.HTML(text) #解析字符串html
print(type(html)) #是一个Element的对象
# Out:
# <class 'lxml.etree._Element'>

# %%
# 转换成html对象并解码
print(etree.tostring(htmlElement, encoding='utf-8').decode('utf-8'))
## 将htmlElement转换成html代码
## 进行了规范化，比如：<html><body>等等等
# Out:
# <html><body><table class="tablelist" cellpadding="0" cellspacing="0">
#     <tbody>
#         <tr class="h">
#             <td class="l" width="374">职位名称</td>
#             <td>职位类别</td>
#             <td>人数</td>
#             <td>地点</td>
#             <td>发布时间</td>
#         </tr>
#         <tr class="even">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=33824&amp;keywords=python&amp;tid=87&amp;lid=2218">22989-金融云区块链高级研发工程师（深圳）</a></td>
#             <td>技术类</td>
#             <td>1</td>
#             <td>深圳</td>
#             <td>2017-11-25</td>
#         </tr>
#         <tr class="odd">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=29938&amp;keywords=python&amp;tid=87&amp;lid=2218">22989-金融云高级后台开发</a></td>
#             <td>技术类</td>
#             <td>2</td>
#             <td>深圳</td>
#             <td>2017-11-25</td>
#         </tr>
#         <tr class="even">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=31236&amp;keywords=python&amp;tid=87&amp;lid=2218">SNG16-腾讯音乐运营开发工程师（深圳）</a></td>
#             <td>技术类</td>
#             <td>2</td>
#             <td>深圳</td>
#             <td>2017-11-25</td>
#         </tr>
#         <tr class="odd">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=31235&amp;keywords=python&amp;tid=87&amp;lid=2218">SNG16-腾讯音乐业务运维工程师（深圳）</a></td>
#             <td>技术类</td>
#             <td>1</td>
#             <td>深圳</td>
#             <td>2017-11-25</td>
#         </tr>
#         <tr class="even">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=34531&amp;keywords=python&amp;tid=87&amp;lid=2218">TEG03-高级研发工程师（深圳）</a></td>
#             <td>技术类</td>
#             <td>1</td>
#             <td>深圳</td>
#             <td>2017-11-24</td>
#         </tr>
#         <tr class="odd">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=34532&amp;keywords=python&amp;tid=87&amp;lid=2218">TEG03-高级图像算法研发工程师（深圳）</a></td>
#             <td>技术类</td>
#             <td>1</td>
#             <td>深圳</td>
#             <td>2017-11-24</td>
#         </tr>
#         <tr class="even">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=31648&amp;keywords=python&amp;tid=87&amp;lid=2218">TEG11-高级AI开发工程师（深圳）</a></td>
#             <td>技术类</td>
#             <td>4</td>
#             <td>深圳</td>
#             <td>2017-11-24</td>
#         </tr>
#         <tr class="odd">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=32218&amp;keywords=python&amp;tid=87&amp;lid=2218">15851-后台开发工程师</a></td>
#             <td>技术类</td>
#             <td>1</td>
#             <td>深圳</td>
#             <td>2017-11-24</td>
#         </tr>
#         <tr class="even">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=32217&amp;keywords=python&amp;tid=87&amp;lid=2218">15851-后台开发工程师</a></td>
#             <td>技术类</td>
#             <td>1</td>
#             <td>深圳</td>
#             <td>2017-11-24</td>
#         </tr>
#         <tr class="odd">
#             <td class="l square"><a target="_blank" href="position_detail.php?id=34511&amp;keywords=python&amp;tid=87&amp;lid=2218">SNG11-高级业务运维工程师（深圳）</a></td>
#             <td>技术类</td>
#             <td>1</td>
#             <td>深圳</td>
#             <td>2017-11-24</td>
#         </tr>
#     </tbody>
# </table>
# </body></html>

# %%
# 我们定义一个函数
def parse_text():
    htmlElement = etree.HTML(text) #.HTML:这里的话会默认用HTML解析器
    print(etree.tostring(htmlElement, encoding='utf-8').decode('utf-8'))

def parse_file():
    parser = etree.HTMLParser(encoding='utf-8') #因为默认的是XML解析器，我们要的是HTML
    htmlElement = etree.parse("lagou.html",parser=parser)
    print(etree.tostring(htmlElement, encoding='utf-8').decode('utf-8'))
    
if __name__ == '__main__':
    parse_file()
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">
# <html><body><ul class="item_con_list" style="display: block;">&#13;
#     &#13;
#     <li class="con_list_item first_row default_list" data-index="0" data-positionid="5077501" data-salary="8k-15k" data-company="猎户星空" data-positionname="培训专员/经理" data-companyid="172285" data-hrid="8705749" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5077501.html" target="_blank" data-index="0" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0101&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5077501" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">培训专员/经理</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">北京·朝阳区</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image/M00/93/B1/CgpEMlsLvTCAcXLTAAUmn-Cylzc923.jpg"/>&#13;
#                             <input type="hidden" class="hr_name" value="方娜"/>&#13;
#                             <input type="hidden" class="hr_position" value="HRBP"/>&#13;
#                             <input type="hidden" class="target_hr" value="8705749"/>&#13;
#                             <input type="hidden" class="target_position" value="5077501"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0101" data-lg-tj-cid="172285" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"/>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">8k-15k</span>&#13;
#                         <!--<i></i>-->经验1-3年 / 本科&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/172285.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0101&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="172285" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">猎户星空</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     移动互联网,硬件 / A轮 / 500-2000人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/172285.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0101&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="172285" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image2/M00/11/01/CgotOVnp25qABPNEAAAPCU2v4tA280.png" alt="猎户星空" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         <span>HR</span>&#13;
#                     &#13;
#                         <span>员工培训</span>&#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“六险一金,福利多,open,牛人多”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="1" data-positionid="5080869" data-salary="5k-7k" data-company="易代" data-positionname="文案策划" data-companyid="300824" data-hrid="11485685" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5080869.html" target="_blank" data-index="1" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0102&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5080869" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">文案策划</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">广州</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image2/M01/7C/43/CgotOVtzwvKAEiDlAAAdzm2coA4297.jpg"/>&#13;
#                             <input type="hidden" class="hr_name" value="HR"/>&#13;
#                             <input type="hidden" class="hr_position" value="人事行政"/>&#13;
#                             <input type="hidden" class="target_hr" value="11485685"/>&#13;
#                             <input type="hidden" class="target_position" value="5080869"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0102" data-lg-tj-cid="300824" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1">&#13;
# 	<div class="chat_pop_up">&#13;
# 		<span class="arrow"/>&#13;
# 		<dl class="chat_main clearfix">&#13;
# 			<dt><div class="chat_qrcode"><canvas width="116" height="116"/></div></dt>&#13;
# 			<dd>&#13;
# 				<dl class="chat_head clearfix">&#13;
# 					<dt>&#13;
# 						&#13;
# 							<img class="hr_headpic" src="https://www.lgstatic.com/i/image2/M01/7C/43/CgotOVtzwvKAEiDlAAAdzm2coA4297.jpg" alt="hr头像" width="62" height="62"/>&#13;
# 						&#13;
# 					</dt>&#13;
# 					<dd>&#13;
# 						<div class="hr_name">HR</div>&#13;
# 						<div class="hr_position">人事行政</div>&#13;
# 					</dd>&#13;
# 					<dd class="tips_text">Hi，对我发布的职位感兴趣？用拉勾APP扫码，直接和我聊聊吧！</dd>&#13;
# 				</dl>&#13;
# 			</dd>&#13;
# 		</dl>&#13;
# 	</div>&#13;
# &#13;
# </div>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">5k-7k</span>&#13;
#                         <!--<i></i>-->经验1-3年 / 不限&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/300824.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0102&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="300824" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">易代</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     电子商务 / A轮 / 50-150人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/300824.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0102&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="300824" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image2/M01/7C/55/CgoB5ltz03mASSwoAAAdzm2coA4930.jpg" alt="易代" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         &#13;
#                             <span>""</span>&#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“电商,文案,策划”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="2" data-positionid="5080868" data-salary="4k-7k" data-company="河南芝马互动科技有限公司" data-positionname="策划" data-companyid="374646" data-hrid="10045557" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5080868.html" target="_blank" data-index="2" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0103&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5080868" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">策划</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">郑州</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image2/M01/85/1E/CgotOVuJEYqADxBaAAGNcvR-wPQ479.png"/>&#13;
#                             <input type="hidden" class="hr_name" value="李培培"/>&#13;
#                             <input type="hidden" class="hr_position" value="人力资源部"/>&#13;
#                             <input type="hidden" class="target_hr" value="10045557"/>&#13;
#                             <input type="hidden" class="target_position" value="5080868"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0103" data-lg-tj-cid="374646" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1">&#13;
# 	<div class="chat_pop_up">&#13;
# 		<span class="arrow"/>&#13;
# 		<dl class="chat_main clearfix">&#13;
# 			<dt><div class="chat_qrcode"><canvas width="116" height="116"/></div></dt>&#13;
# 			<dd>&#13;
# 				<dl class="chat_head clearfix">&#13;
# 					<dt>&#13;
# 						&#13;
# 							<img class="hr_headpic" src="https://www.lgstatic.com/i/image2/M01/85/1E/CgotOVuJEYqADxBaAAGNcvR-wPQ479.png" alt="hr头像" width="62" height="62"/>&#13;
# 						&#13;
# 					</dt>&#13;
# 					<dd>&#13;
# 						<div class="hr_name">李培培</div>&#13;
# 						<div class="hr_position">人力资源部</div>&#13;
# 					</dd>&#13;
# 					<dd class="tips_text">Hi，对我发布的职位感兴趣？用拉勾APP扫码，直接和我聊聊吧！</dd>&#13;
# 				</dl>&#13;
# 			</dd>&#13;
# 		</dl>&#13;
# 	</div>&#13;
# &#13;
# </div>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">4k-7k</span>&#13;
#                         <!--<i></i>-->经验1-3年 / 本科&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/374646.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0103&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="374646" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">河南芝马互动科技有限公司</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     移动互联网,金融 / 未融资 / 15-50人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/374646.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0103&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="374646" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image2/M01/85/20/CgoB5luJEbGANrZHAAGNcvR-wPQ685.png" alt="河南芝马互动科技有限公司" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         <span>文案</span>&#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“五险,双休,交补餐补,CBD地铁”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="3" data-positionid="5056561" data-salary="20k-30k" data-company="方趣网络" data-positionname="手游主美" data-companyid="107291" data-hrid="3218460" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5056561.html" target="_blank" data-index="3" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0104&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5056561" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">手游主美</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">上海·闵行区</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image3/M00/4F/21/Cgq2xlrxCKSAUByYAAIKj-J2OSc309.jpg"/>&#13;
#                             <input type="hidden" class="hr_name" value="hr"/>&#13;
#                             <input type="hidden" class="hr_position" value="HR"/>&#13;
#                             <input type="hidden" class="target_hr" value="3218460"/>&#13;
#                             <input type="hidden" class="target_position" value="5056561"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0104" data-lg-tj-cid="107291" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"/>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">20k-30k</span>&#13;
#                         <!--<i></i>-->经验3-5年 / 大专&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/107291.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0104&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="107291" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">方趣网络</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     游戏 / A轮 / 50-150人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/107291.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0104&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="107291" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image/M00/00/A1/CgqKkVZQRN2ABS2pAAIIY8sCsVM330.jpg" alt="方趣网络" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         <span>游戏</span>&#13;
#                     &#13;
#                         <span>原画</span>&#13;
#                     &#13;
#                         <span>2D</span>&#13;
#                     &#13;
#                         <span>特效</span>&#13;
#                     &#13;
#                         <span>动画</span>&#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“福利好,氛围好,机会多,双休”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="4" data-positionid="5076860" data-salary="5k-8k" data-company="飞梭智行" data-positionname="C++后台开发工程师（实习）" data-companyid="430065" data-hrid="11408520" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5076860.html" target="_blank" data-index="4" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0105&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5076860" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">C++后台开发工程师（实习）</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">上海·普陀区</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image2/M01/75/CB/CgoB5ltj-D6AW4uGAAAmcTPKN74759.JPG"/>&#13;
#                             <input type="hidden" class="hr_name" value="Dennis Cao"/>&#13;
#                             <input type="hidden" class="hr_position" value="软件部负责人"/>&#13;
#                             <input type="hidden" class="target_hr" value="11408520"/>&#13;
#                             <input type="hidden" class="target_position" value="5076860"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0105" data-lg-tj-cid="430065" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"/>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">5k-8k</span>&#13;
#                         <!--<i></i>-->经验不限 / 本科&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/430065.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0105&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="430065" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">飞梭智行</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     硬件,人工智能 / 不需要融资 / 50-150人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/430065.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0105&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="430065" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image2/M01/76/97/CgoB5ltniAWARrguAAALx7Zbzmg968.jpg" alt="飞梭智行" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         <span>移动互联网</span>&#13;
#                     &#13;
#                         <span>移动互联网</span>&#13;
#                     &#13;
#                         <span>后端</span>&#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“有竞争力的收入，及餐补等福利”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="5" data-positionid="5080866" data-salary="30k-50k" data-company="美团点评" data-positionname="财务高级Java开发工程师-北京" data-companyid="50702" data-hrid="4699364" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5080866.html" target="_blank" data-index="5" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0106&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5080866" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">财务高级Java开发工程师-北京</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">北京</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image3/M00/05/3C/Cgq2xlpe5QiAK4aVAAAbIwlOR2M232.jpg"/>&#13;
#                             <input type="hidden" class="hr_name" value="lagoujianli"/>&#13;
#                             <input type="hidden" class="hr_position" value=""/>&#13;
#                             <input type="hidden" class="target_hr" value="4699364"/>&#13;
#                             <input type="hidden" class="target_position" value="5080866"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0106" data-lg-tj-cid="50702" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"/>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">30k-50k</span>&#13;
#                         <!--<i></i>-->经验5-10年 / 本科&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/50702.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0106&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="50702" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">美团点评</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     移动互联网,O2O / D轮及以上 / 2000人以上&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/50702.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0106&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="50702" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image/M00/6A/05/Cgp3O1gW8zSAUwUsAABMptH-XY087.jpeg" alt="美团点评" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         &#13;
#                             <span>技能培训</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>绩效奖金</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>岗位晋升</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>领导好</span>&#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“晋升机会多”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="6" data-positionid="5080864" data-salary="10k-20k" data-company="金投手" data-positionname="高级测试工程师" data-companyid="56118" data-hrid="1410786" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5080864.html" target="_blank" data-index="6" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0107&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5080864" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">高级测试工程师</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">北京</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image/M00/74/17/CgpFT1pAq_GAOsZuAAAfjr4PSec681.JPG"/>&#13;
#                             <input type="hidden" class="hr_name" value="丁女士"/>&#13;
#                             <input type="hidden" class="hr_position" value="招聘经理"/>&#13;
#                             <input type="hidden" class="target_hr" value="1410786"/>&#13;
#                             <input type="hidden" class="target_position" value="5080864"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0107" data-lg-tj-cid="56118" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1">&#13;
# 	<div class="chat_pop_up">&#13;
# 		<span class="arrow"/>&#13;
# 		<dl class="chat_main clearfix">&#13;
# 			<dt><div class="chat_qrcode"><canvas width="116" height="116"/></div></dt>&#13;
# 			<dd>&#13;
# 				<dl class="chat_head clearfix">&#13;
# 					<dt>&#13;
# 						&#13;
# 							<img class="hr_headpic" src="https://www.lgstatic.com/i/image/M00/74/17/CgpFT1pAq_GAOsZuAAAfjr4PSec681.JPG" alt="hr头像" width="62" height="62"/>&#13;
# 						&#13;
# 					</dt>&#13;
# 					<dd>&#13;
# 						<div class="hr_name">丁女士</div>&#13;
# 						<div class="hr_position">招聘经理</div>&#13;
# 					</dd>&#13;
# 					<dd class="tips_text">Hi，对我发布的职位感兴趣？用拉勾APP扫码，直接和我聊聊吧！</dd>&#13;
# 				</dl>&#13;
# 			</dd>&#13;
# 		</dl>&#13;
# 	</div>&#13;
# &#13;
# </div>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">10k-20k</span>&#13;
#                         <!--<i></i>-->经验3-5年 / 本科&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/56118.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0107&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="56118" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">金投手</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     移动互联网,金融 / 不需要融资 / 150-500人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/56118.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0107&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="56118" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image/M00/AB/85/CgqKkVizmy-ACu8dAAAghzux1x4186.JPG" alt="金投手" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         &#13;
#                             <span>节日礼物</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>带薪年假</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>零食饮料</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>岗位晋升</span>&#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“扁平化管理,晋升空间大,弹性工作,团建”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="7" data-positionid="5078427" data-salary="20k-30k" data-company="蓝薪卡" data-positionname="PHP后端开发工程师（yii框架）" data-companyid="288550" data-hrid="6477766" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5078427.html" target="_blank" data-index="7" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0108&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5078427" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">PHP后端开发工程师（yii框架）</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     <span class="add">[<em class="">上海·八佰伴</em>]</span>&#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image2/M01/65/43/CgotOVs_EnqAPbDMAAAU37rdk7g832.jpg"/>&#13;
#                             <input type="hidden" class="hr_name" value="Louise Zhang"/>&#13;
#                             <input type="hidden" class="hr_position" value="HR Manager"/>&#13;
#                             <input type="hidden" class="target_hr" value="6477766"/>&#13;
#                             <input type="hidden" class="target_position" value="5078427"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0108" data-lg-tj-cid="288550" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"/>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">20k-30k</span>&#13;
#                         <!--<i></i>-->经验3-5年 / 本科&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/288550.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0108&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="288550" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">蓝薪卡</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     移动互联网 / 未融资 / 50-150人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/288550.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0108&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="288550" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image2/M01/6C/A9/CgoB5ltO-dOAA2UhAAC1vfbiDIc438.png" alt="蓝薪卡" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         &#13;
#                             <span>年底双薪</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>股票期权</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>年终分红</span>&#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <span>绩效奖金</span>&#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“加班不多,空间大,氛围好,6个月分红”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="8" data-positionid="5080863" data-salary="7k-14k" data-company="杭州司塔科信息安全技术有限公司" data-positionname="销售经理" data-companyid="422361" data-hrid="11311409" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5080863.html" target="_blank" data-index="8" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0109&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="5080863" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">销售经理</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">杭州</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:19发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image2/M01/6D/D3/CgoB5ltRW4GAL2ziAAAoIuR7D40781.png"/>&#13;
#                             <input type="hidden" class="hr_name" value="李洋"/>&#13;
#                             <input type="hidden" class="hr_position" value="HR主管"/>&#13;
#                             <input type="hidden" class="target_hr" value="11311409"/>&#13;
#                             <input type="hidden" class="target_position" value="5080863"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0109" data-lg-tj-cid="422361" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"/>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">7k-14k</span>&#13;
#                         <!--<i></i>-->经验3-5年 / 本科&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/422361.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0109&#13;&#10;                    &#13;&#10;                &#13;&#10;                " data-lg-tj-cid="422361" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">杭州司塔科信息安全技术有限公司</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     信息安全,数据服务 / 未融资 / 15-50人&#13;
#                 </div>&#13;
#             </div>&#13;
# ...
#                     &#13;
#                         <span>用户研究</span>&#13;
#                     &#13;
#                         <span>产品设计</span>&#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“晋升空间大,领导好,环境好”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="12" data-positionid="5057721" data-salary="6k-12k" data-company="有米科技" data-positionname="营销号编辑" data-companyid="271" data-hrid="60168" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5057721.html" target="_blank" data-index="12" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0113&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="5057721" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">营销号编辑</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     <span class="add">[<em class="">广州·大学城</em>]</span>&#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:18发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value=""/>&#13;
#                             <input type="hidden" class="hr_name" value="hr"/>&#13;
#                             <input type="hidden" class="hr_position" value=""/>&#13;
#                             <input type="hidden" class="target_hr" value="60168"/>&#13;
#                             <input type="hidden" class="target_position" value="5057721"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0113" data-lg-tj-cid="271" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"/>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">6k-12k</span>&#13;
#                         <!--<i></i>-->经验1-3年 / 本科&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/271.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0113&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="271" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">有米科技</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     移动互联网,广告营销 / 上市公司 / 500-2000人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/271.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0113&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="271" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image/M00/89/F9/CgpEMlrOwKSAaQrJAABLv07m6Y4833.jpg" alt="有米科技" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         <span>广告营销</span>&#13;
#                     &#13;
#                         <span>移动互联网</span>&#13;
#                     &#13;
#                         <span>文案</span>&#13;
#                     &#13;
#                         <span>采编</span>&#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“六险一金,员工福利多,工作氛围好,扁平化管理”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="13" data-positionid="5065729" data-salary="4k-6k" data-company="尚美缤纷" data-positionname="业务员" data-companyid="222457" data-hrid="8342165" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5065729.html" target="_blank" data-index="13" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0114&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="5065729" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">业务员</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     <span class="add">[<em class="">成都·玉林</em>]</span>&#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:18发布</span>&#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value=""/>&#13;
#                             <input type="hidden" class="hr_name" value="Eric"/>&#13;
#                             <input type="hidden" class="hr_position" value=""/>&#13;
#                             <input type="hidden" class="target_hr" value="8342165"/>&#13;
#                             <input type="hidden" class="target_position" value="5065729"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0114" data-lg-tj-cid="222457" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1"/>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">4k-6k</span>&#13;
#                         <!--<i></i>-->经验1-3年 / 大专&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/222457.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0114&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="222457" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">尚美缤纷</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     电子商务,O2O / 不需要融资 / 15-50人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/222457.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0114&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="222457" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image/M00/6E/7D/CgpEMlmwobuAJ-5QAAAehgtTDKg823.png" alt="尚美缤纷" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         <span>商务渠道</span>&#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“五险一金,年终奖,法定福利”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     &#13;
#     &#13;
#     <li class="con_list_item default_list" data-index="14" data-positionid="5040905" data-salary="4k-6k" data-company="八九间" data-positionname="电商客服" data-companyid="441144" data-hrid="11535251" data-tpladword="0">&#13;
#         &#13;
#         <div class="list_item_top">&#13;
#             <div class="position">&#13;
#                 <div class="p_top">&#13;
#                     <a class="position_link" href="https://www.lagou.com/jobs/5040905.html" target="_blank" data-index="14" data-lg-tj-id="8E00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0115&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="5040905" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">&#13;
#                         <h3 style="max-width: 180px;">电商客服</h3>&#13;
#                         &#13;
#                             &#13;
#                                 &#13;
#                                     &#13;
#                                         <span class="add">[<em class="">杭州·余杭区</em>]</span>&#13;
#                                     &#13;
#                                 &#13;
#                             &#13;
#                         &#13;
# &#13;
#                     </a>&#13;
#                     <span class="format-time">10:18发布</span>&#13;
#                     &#13;
#                         &#13;
#                             <input type="hidden" class="hr_portrait" value="i/image2/M01/80/8D/CgotOVt-HvKAK6J6AAZFehgnMQ0479.png"/>&#13;
#                             <input type="hidden" class="hr_name" value="杨会"/>&#13;
#                             <input type="hidden" class="hr_position" value="HR"/>&#13;
#                             <input type="hidden" class="target_hr" value="11535251"/>&#13;
#                             <input type="hidden" class="target_position" value="5040905"/>&#13;
#                             &#13;
#                             <div class="chat_me" data-lg-tj-id="1WI0" data-lg-tj-no="0115" data-lg-tj-cid="441144" data-lg-tj-track-code="search_code" data-lg-tj-track-type="1">&#13;
# 	<div class="chat_pop_up">&#13;
# 		<span class="arrow"/>&#13;
# 		<dl class="chat_main clearfix">&#13;
# 			<dt><div class="chat_qrcode"><canvas width="116" height="116"/></div></dt>&#13;
# 			<dd>&#13;
# 				<dl class="chat_head clearfix">&#13;
# 					<dt>&#13;
# 						&#13;
# 							<img class="hr_headpic" src="https://www.lgstatic.com/i/image2/M01/80/8D/CgotOVt-HvKAK6J6AAZFehgnMQ0479.png" alt="hr头像" width="62" height="62"/>&#13;
# 						&#13;
# 					</dt>&#13;
# 					<dd>&#13;
# 						<div class="hr_name">杨会</div>&#13;
# 						<div class="hr_position">HR</div>&#13;
# 					</dd>&#13;
# 					<dd class="tips_text">Hi，对我发布的职位感兴趣？用拉勾APP扫码，直接和我聊聊吧！</dd>&#13;
# 				</dl>&#13;
# 			</dd>&#13;
# 		</dl>&#13;
# 	</div>&#13;
# &#13;
# </div>&#13;
#                             &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                         &#13;
#                     &#13;
#                 </div>&#13;
#                 <div class="p_bot">&#13;
#                     <div class="li_b_l">&#13;
#                         <span class="money">4k-6k</span>&#13;
#                         <!--<i></i>-->经验不限 / 不限&#13;
#                     </div>&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="company">&#13;
#                 <div class="company_name">&#13;
#                     <a href="https://www.lagou.com/gongsi/441144.html" target="_blank" data-lg-tj-id="8F00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0115&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="441144" data-lg-tj-abt="dm-csearch-useUserAllInterest|0">八九间</a><i class="company_mark"><span>该企业已上传营业执照并通过资质验证审核</span></i>&#13;
#                 </div>&#13;
#                 <div class="industry">&#13;
#                     电子商务 / 不需要融资 / 15-50人&#13;
#                 </div>&#13;
#             </div>&#13;
#             <div class="com_logo">&#13;
#                 <a href="https://www.lagou.com/gongsi/441144.html" target="_blank" data-lg-tj-id="8G00" data-lg-tj-no="&#13;&#10;                &#13;&#10;                    &#13;&#10;                    0115&#13;&#10;                    &#13;&#10;               &#13;&#10;                " data-lg-tj-cid="441144" data-lg-tj-abt="dm-csearch-useUserAllInterest|0"><img src="//www.lgstatic.com/thumbnail_120x120/i/image2/M01/80/CD/CgotOVt-Z3KAFwhuAAZFehgnMQ0295.png" alt="八九间" width="60" height="60"/></a>&#13;
#             </div>&#13;
#         </div>&#13;
#         <div class="list_item_bot">&#13;
#             &#13;
#                 <div class="li_b_l">&#13;
#                     &#13;
#                         <span>售前</span>&#13;
#                     &#13;
#                         <span>售后</span>&#13;
#                     &#13;
#                         <span>天猫客服</span>&#13;
#                     &#13;
#                 </div>&#13;
#             &#13;
#             <div class="li_b_r">“淘宝客服,天猫客服,售前客服,售后客服”</div>&#13;
#         </div>&#13;
#     </li>&#13;
#     &#13;
#     </ul></body></html>

# %% [markdown]
# ### lxml结合xpath注意事项

# %%
# 用腾讯招聘作为例子
parser = etree.HTMLParser(encoding='utf-8')
html = etree.parse("tencent.html", parser=parser)

# 1.获取所有的tr标签
# //tr
# xpath函数返回的是一个列表
trs = html.xpath("//tr")
for tr in trs:
    print(etree.tostring(tr, encoding='utf-8').decode('utf-8')) 
    #将element对象转换成html
# Out:
# <tr class="h">&#13;
#             <td class="l" width="374">职位名称</td>&#13;
#             <td>职位类别</td>&#13;
#             <td>人数</td>&#13;
#             <td>地点</td>&#13;
#             <td>发布时间</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=33824&amp;keywords=python&amp;tid=87&amp;lid=2218">22989-金融云区块链高级研发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-25</td>&#13;
#         </tr>&#13;
#
# <tr class="odd">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=29938&amp;keywords=python&amp;tid=87&amp;lid=2218">22989-金融云高级后台开发</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>2</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-25</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=31236&amp;keywords=python&amp;tid=87&amp;lid=2218">SNG16-腾讯音乐运营开发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>2</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-25</td>&#13;
#         </tr>&#13;
#
# <tr class="odd">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=31235&amp;keywords=python&amp;tid=87&amp;lid=2218">SNG16-腾讯音乐业务运维工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-25</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=34531&amp;keywords=python&amp;tid=87&amp;lid=2218">TEG03-高级研发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;
#
# <tr class="odd">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=34532&amp;keywords=python&amp;tid=87&amp;lid=2218">TEG03-高级图像算法研发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=31648&amp;keywords=python&amp;tid=87&amp;lid=2218">TEG11-高级AI开发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>4</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;
#
# <tr class="odd">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=32218&amp;keywords=python&amp;tid=87&amp;lid=2218">15851-后台开发工程师</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=32217&amp;keywords=python&amp;tid=87&amp;lid=2218">15851-后台开发工程师</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;
#
# <tr class="odd">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=34511&amp;keywords=python&amp;tid=87&amp;lid=2218">SNG11-高级业务运维工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;

# %%
# 2.获取第2个tr标签
trs = html.xpath("//tr[2]")[0] #取这个列表中的第一个元素，这里也只有一个，但是xpath返回的是list
print(etree.tostring(tr, encoding='utf-8').decode('utf-8'))
# Out:
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=33824&amp;keywords=python&amp;tid=87&amp;lid=2218">22989-金融云区块链高级研发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-25</td>&#13;
#         </tr>&#13;

# %%
# 3.获取所有class等于even的tr标签
trs = html.xpath("//tr[@class='even']")
for tr in trs:
    print(etree.tostring(tr, encoding='utf-8').decode('utf-8'))
# Out:
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=33824&amp;keywords=python&amp;tid=87&amp;lid=2218">22989-金融云区块链高级研发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-25</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=31236&amp;keywords=python&amp;tid=87&amp;lid=2218">SNG16-腾讯音乐运营开发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>2</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-25</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=34531&amp;keywords=python&amp;tid=87&amp;lid=2218">TEG03-高级研发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=31648&amp;keywords=python&amp;tid=87&amp;lid=2218">TEG11-高级AI开发工程师（深圳）</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>4</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;
#
# <tr class="even">&#13;
#             <td class="l square"><a target="_blank" href="position_detail.php?id=32217&amp;keywords=python&amp;tid=87&amp;lid=2218">15851-后台开发工程师</a></td>&#13;
#             <td>技术类</td>&#13;
#             <td>1</td>&#13;
#             <td>深圳</td>&#13;
#             <td>2017-11-24</td>&#13;
#         </tr>&#13;

# %%
# 4.获取所有a标签的href属性
aList = html.xpath("//a/@href") #获得href对于的值
# 注意：html.path("//a/[@href]") 获取a下所有含有href属性的标签

for a in aList:
    print(a) 
#但是这是https://hr.tencent.com/position_detail.php?id=43871&keywords=&tid=87&lid=0
#后面的部分, 所以我们还需要前面这部分。
#因为点击跳转是在当前域名的基础上进行组合的。
# Out:
# position_detail.php?id=33824&keywords=python&tid=87&lid=2218
# position_detail.php?id=29938&keywords=python&tid=87&lid=2218
# position_detail.php?id=31236&keywords=python&tid=87&lid=2218
# position_detail.php?id=31235&keywords=python&tid=87&lid=2218
# position_detail.php?id=34531&keywords=python&tid=87&lid=2218
# position_detail.php?id=34532&keywords=python&tid=87&lid=2218
# position_detail.php?id=31648&keywords=python&tid=87&lid=2218
# position_detail.php?id=32218&keywords=python&tid=87&lid=2218
# position_detail.php?id=32217&keywords=python&tid=87&lid=2218
# position_detail.php?id=34511&keywords=python&tid=87&lid=2218

# %%
# 那么，如何获取网址的url呢？
for a in aList:
    print("https://hr.tencent.com/" + a)
# Out:
# https://hr.tencent.com/position_detail.php?id=33824&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=29938&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=31236&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=31235&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=34531&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=34532&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=31648&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=32218&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=32217&keywords=python&tid=87&lid=2218
# https://hr.tencent.com/position_detail.php?id=34511&keywords=python&tid=87&lid=2218

# %%
# 5.获取所有的职位信息（纯文本）
# 发现所有的职位信息都是在tr标签下
# 第一个tr标签不需要，因为第一个是类别名称
trs = html.xpath("//tr[position()>1]")
for tr in trs:
    href = tr.xpath("//a")
    print(href)
    break
#？为什么呢，应该只有一个才对。因为//a会在整个网页中寻找，会忽视
# 之前的//tr标签
# Out:
# [<Element a at 0x10951d748>, <Element a at 0x10951dc48>, <Element a at 0x10951dcc8>, <Element a at 0x10951dd48>, <Element a at 0x10951ddc8>, <Element a at 0x10951de88>, <Element a at 0x10951df08>, <Element a at 0x10951df88>, <Element a at 0x109535048>, <Element a at 0x10951de48>]

# %%
# 所以
positions = []
for tr in trs:
    # 在某个标签下，再执行xpath函数，获取这个标签下的子孙元素
    # 那么应该在//之前加一个点，代表是在当前元素下获取
    href = tr.xpath(".//a/@href")[0]
    fullurl = 'https://hr.tencent.com/' + href
    # text() 获取该标签下的所有文本信息
    title = tr.xpath("./td[1]//text()")[0] #或者.//a/text()
    category = tr.xpath("./td[2]//text()")[0]
    address = tr.xpath("./td[4]//text()")[0]
    pubtime = tr.xpath("./td[5]//text()")[0]
    
    #组装成一个字典
    position = {
        'url': fullurl,
        'title': title,
        'category': category,
        'address': address,
        'pubtime': pubtime
    }
    #加入列表
    positions.append(position)

# %%
print(positions)
# Out:
# [{'url': 'https://hr.tencent.com/position_detail.php?id=33824&keywords=python&tid=87&lid=2218', 'title': '22989-金融云区块链高级研发工程师（深圳）', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-25'}, {'url': 'https://hr.tencent.com/position_detail.php?id=29938&keywords=python&tid=87&lid=2218', 'title': '22989-金融云高级后台开发', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-25'}, {'url': 'https://hr.tencent.com/position_detail.php?id=31236&keywords=python&tid=87&lid=2218', 'title': 'SNG16-腾讯音乐运营开发工程师（深圳）', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-25'}, {'url': 'https://hr.tencent.com/position_detail.php?id=31235&keywords=python&tid=87&lid=2218', 'title': 'SNG16-腾讯音乐业务运维工程师（深圳）', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-25'}, {'url': 'https://hr.tencent.com/position_detail.php?id=34531&keywords=python&tid=87&lid=2218', 'title': 'TEG03-高级研发工程师（深圳）', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-24'}, {'url': 'https://hr.tencent.com/position_detail.php?id=34532&keywords=python&tid=87&lid=2218', 'title': 'TEG03-高级图像算法研发工程师（深圳）', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-24'}, {'url': 'https://hr.tencent.com/position_detail.php?id=31648&keywords=python&tid=87&lid=2218', 'title': 'TEG11-高级AI开发工程师（深圳）', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-24'}, {'url': 'https://hr.tencent.com/position_detail.php?id=32218&keywords=python&tid=87&lid=2218', 'title': '15851-后台开发工程师', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-24'}, {'url': 'https://hr.tencent.com/position_detail.php?id=32217&keywords=python&tid=87&lid=2218', 'title': '15851-后台开发工程师', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-24'}, {'url': 'https://hr.tencent.com/position_detail.php?id=34511&keywords=python&tid=87&lid=2218', 'title': 'SNG11-高级业务运维工程师（深圳）', 'category': '技术类', 'address': '深圳', 'pubtime': '2017-11-24'}]
